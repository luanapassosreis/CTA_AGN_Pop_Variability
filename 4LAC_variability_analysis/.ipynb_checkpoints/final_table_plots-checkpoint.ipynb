# %%
from read_json import *
from spectrum_integrate import *
from plots import *
from source_filter import *
from variability_estimator import *

# %%
import glob
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.table import Table

# %%
## import

path_4lac_dr3_catalog = '../4LAC_catalog_generator_v3/resulting_catalogs/agn_pop_4lac_dr3.ecsv'
table_agn_pop_4lac_dr3 = Table.read(path_4lac_dr3_catalog, format='ascii.ecsv')
df_agn_pop_4lac_dr3 = table_agn_pop_4lac_dr3.to_pandas()

df_agn_pop_4lac_dr3.head()
# Out:
#     Source_Name  RAJ2000    DEJ2000  Redshift SpectrumType  Pivot_Energy  \
# 0  J0001.2+4741   0.3126  47.685902      -inf     PowerLaw   2420.575195
# 1  J0001.2-0747   0.3151  -7.797100      -inf     PowerLaw   1721.603882
# 2  J0001.4-0010   0.3717  -0.169900  0.461516     PowerLaw   4307.082520
# 3  J0001.5+2113   0.3815  21.218300  1.106000  LogParabola    329.773743
# 4  J0001.6-4156   0.4165 -41.942501      -inf     PowerLaw   4047.030029
#
#    PL_Flux_Density  PL_Index  LP_Flux_Density  LP_Index   LP_beta CLASS  \
# 0     2.156031e-14  2.271696     2.196550e-14  2.254081  0.012156   bcu
# 1     2.656894e-13  2.116692     2.842831e-13  2.078927  0.051182   bll
# 2     6.067356e-15  1.939160     6.488817e-15  1.661223  0.132438   bll
# 3     4.683598e-11  2.654060     5.371562e-11  2.514159  0.159319  fsrq
# 4     1.881541e-14  1.775175     2.131597e-14  1.693865  0.072754   bcu
#
#   SED_class  Variability_Index  Frac_Variability  Unc_Frac_Variability  \
# 0       ISP          25.313953          0.675882              0.312850
# 1       LSP          46.780693          0.406565              0.111870
# 2       LSP           9.272764          0.000000             10.000000
# 3       ISP        1910.935791          0.996138              0.213478
# 4       HSP          26.393343          0.490977              0.175782
#
#        Flux1000  Unc_Flux1000
# 0  1.259796e-10  2.877197e-11
# 1  7.471219e-10  5.041939e-11
# 2  1.082246e-10  2.914440e-11
# 3  1.347354e-09  6.172809e-11
# 4  2.821817e-10  3.090882e-11

# %%
## saving our changes in a separate dataframe

df_4lac_luana_dr3 = df_agn_pop_4lac_dr3.copy()

# %%
df_4lac_luana_dr3 = df_4lac_luana_dr3.drop(df_4lac_luana_dr3.columns[5:11], axis=1)
df_4lac_luana_dr3 = df_4lac_luana_dr3.drop(columns=['RAJ2000', 'DEJ2000', 'Redshift', 'Flux1000', 'Unc_Flux1000'])

# %%
## adding spectrum flux calculations

spectrum_flux_values = []

for index, row in df_4lac_luana_dr3.iterrows():
    source_name = row['Source_Name']
    
    # Integrate from 0.1-100 GeV
    spectrum_flux, diff_flux, spec_type = integrate_spectrum_flux(source_name, df_agn_pop_4lac_dr3, 0.1, 100)
    spectrum_flux_values.append(spectrum_flux)

df_4lac_luana_dr3['Spectrum_Flux_Estimated'] = spectrum_flux_values
# Out:
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/spectrum_integrate.py:71: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   flux_from_spectrum = integrate.quad(lambda x: K * ((x/E_0)**(- alpha - beta * np.log(x/E_0))),

# %%
source_names = df_4lac_luana_dr3['Source_Name'].tolist()

len(source_names)
# Out:
# 3814

# %%
## getting a list of the downloaded sources

folder_path = '../4LAC_lightcurve_downloader_v3/resulting_catalogs/input_lightcurve_downloads_v3/fixed_indexed_lightcurves/3days_ts1_fixedindex_lightcurves'

## glob to get all .json files in the folder
json_files = glob.glob(os.path.join(folder_path, '*.json'))
json_file_names = [os.path.basename(file)[5:17] for file in json_files]

len(json_file_names)
# Out:
# 1429

# %%
## creating a df for the downloaded sources

df_filtered_4lac_luana_dr3 = df_4lac_luana_dr3[df_4lac_luana_dr3['Source_Name'].isin(json_file_names)].copy()
df_filtered_4lac_luana_dr3.reset_index(drop=True, inplace=True)

print(len(df_filtered_4lac_luana_dr3))
# Out:
# 1429

# %%
df_filtered_4lac_luana_dr3
# Out:
#        Source_Name SpectrumType CLASS SED_class  Variability_Index  \
# 0     J0001.2-0747     PowerLaw   bll       LSP          46.780693
# 1     J0001.5+2113  LogParabola  fsrq       ISP        1910.935791
# 2     J0003.3-1928  LogParabola   bcu       LSP          49.879936
# 3     J0004.3+4614  LogParabola  fsrq       LSP         139.036758
# 4     J0004.4-4737     PowerLaw  fsrq       LSP         153.286484
# ...            ...          ...   ...       ...                ...
# 1424  J2358.0-4601     PowerLaw   bcu       LSP          30.538687
# 1425  J2358.3-1021  LogParabola  fsrq       LSP         195.553940
# 1426  J2358.3+3830     PowerLaw   bll       NaN          42.173111
# 1427  J2359.0+3922     PowerLaw  fsrq       LSP          56.146664
# 1428  J2359.2-3134     PowerLaw  fsrq       LSP          82.691574
#
#       Frac_Variability  Unc_Frac_Variability  Spectrum_Flux_Estimated
# 0             0.406565              0.111870             9.825299e-09
# 1             0.996138              0.213478             6.391699e-08
# 2             0.591879              0.159972             3.715681e-09
# 3             1.016224              0.234237             1.086787e-08
# 4             0.823498              0.188146             1.070792e-08
# ...                ...                   ...                      ...
# 1424          0.477398              0.157409             5.184782e-09
# 1425          0.668076              0.150551             2.164930e-08
# 1426          0.567347              0.164919             4.248420e-09
# 1427          0.779921              0.203910             7.005793e-09
# 1428          1.012355              0.248552             5.776904e-09
#
# [1429 rows x 8 columns]

# %%
json_source_names = df_filtered_4lac_luana_dr3['Source_Name'].tolist()

len(json_source_names)
# Out:
# 1429

# %% [markdown]
# ## Filter data - step 1:
# ## remove source if n° Upper Limits > n° flux measurements

# %%
bin_3days = []
bin_weekly = []
bin_monthly = []

bright_ratio_3days = []
filtered_UL_3days = []
        
for i in json_source_names:
    for j in ['3-days', 'weekly', 'monthly']:
    
        # source_data = Read_json_file(file_name, binning, index)
        source_data = Read_json_file(f'4FGL+{i}.json', j, 'fixed')
        source_df = source_data.dataframe
        source_dict = source_data.dictionary
        
        if j == '3-days':
            ratio = len(source_dict['flux_upper_limits']) / len(source_dict['flux'])
            bright_ratio_3days.append(ratio)

        ## check if the number of flux upper limits is less than or equal to flux values
        if len(source_dict['flux_upper_limits']) <= len(source_dict['flux']):
            if j == '3-days':
                filtered_UL_3days.append(ratio)
                bin_3days.append(i)
            elif j == 'weekly':
                bin_weekly.append(i)
            elif j == 'monthly':
                bin_monthly.append(i)

# %%
print('AFTER UPPER LIMIT 50% cut:')
print('3-days bin:', len(bin_3days), 'sources')
print('Weekly bin:', len(bin_weekly), 'sources')
print('Monthly bin:', len(bin_monthly), 'sources')
# Out:
# AFTER UPPER LIMIT 50% cut:
# 3-days bin: 173 sources
# Weekly bin: 339 sources
# Monthly bin: 803 sources

# %%
len(bright_ratio_3days)
len(filtered_UL_3days)
# Out:
# 173

# %%
plt.figure(figsize=(10, 6))
plt.hist(bright_ratio_3days, bins=20, edgecolor='black')
plt.title(f'Histogram of Bright Ratio for 3-Days Binning - {len(bright_ratio_3days)} points')
plt.xlabel('Bright Ratio')
plt.ylabel('Frequency')
plt.grid(True)
plt.savefig('plots/extra/bright_ratio_3days.png',dpi=300)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(filtered_UL_3days, bins=20, edgecolor='black')
plt.title(f'Histogram of Bright Ratio for 3-Days Binning after 50% UL cut - {len(filtered_UL_3days)} points')
plt.xlabel('Bright Ratio')
plt.ylabel('Frequency')
plt.grid(True)
plt.savefig('plots/extra/bright_ratio_3days_withULcut.png',dpi=300)
plt.show()

# %% [markdown]
# # Filter data - step 2:
# -  make the point an UL if TS < 10,
# -  remove the flux points in which:
#     - flux_error = 0,
#     - fit_convergence !=0
#     - exposure (flux / flux_error²) < 1e7 cm²s

# %%
## 3-days

source_names_3days_fixed = []
sigma_nxs_3days_fixed = []
err_sigma_nxs_3days_fixed = []
fvar_3days_fixed = []
unc_fvar_3days_fixed = []

for source_name in bin_3days:
    
    file_name = f'4FGL+{source_name}.json'
    source_data = Read_json_file(file_name, '3-days', 'fixed')
    source_df = source_data.dataframe
    source_dict = source_data.dictionary
    
    filtered_df = filter_source_flux(source_df)
    
    variability = Estimate_variability(filtered_df)
    sigma_nxs, err_sigma_nxs, fvar, err_fvar = variability.calculate_variability()
    
    source_names_3days_fixed.append(source_name)
    sigma_nxs_3days_fixed.append(sigma_nxs)
    err_sigma_nxs_3days_fixed.append(err_sigma_nxs)
    fvar_3days_fixed.append(fvar)
    unc_fvar_3days_fixed.append(err_fvar)
    
df_variability_3days_fixed = pd.DataFrame(list(zip(source_names_3days_fixed,
                                                     sigma_nxs_3days_fixed, err_sigma_nxs_3days_fixed,
                                                     fvar_3days_fixed, unc_fvar_3days_fixed)),
                                            columns =['Source_Name', 'Norm_Excess_Var(3-days)', 'err_Norm_Excess_Var(3-days)',
                                                      'Fvar(3-days)', 'err_Fvar(3-days)'])

# %%
df_variability_3days_fixed
# Out:
#       Source_Name  Norm_Excess_Var(3-days)  err_Norm_Excess_Var(3-days)  \
# 0    J0043.8+3425                -0.019471                     0.015863
# 1    J0050.7-0929                -0.049708                     0.011065
# 2    J0102.8+5824                 0.195591                     0.015823
# 3    J0108.6+0134                 0.961225                     0.009988
# 4    J0112.1+2245                 0.180104                     0.010745
# ..            ...                      ...                          ...
# 168  J2323.5-0317                 0.382500                     0.023621
# 169  J2329.3-4955                 0.650813                     0.013029
# 170  J2345.2-1555                 0.538446                     0.018728
# 171  J2347.0+5141                -0.107116                     0.017116
# 172  J2348.0-1630                 0.374049                     0.017906
#
#      Fvar(3-days)  err_Fvar(3-days)
# 0        0.000000          0.100000
# 1        0.000000          0.100000
# 2        0.442256          0.017888
# 3        0.980421          0.005094
# 4        0.424387          0.012660
# ..            ...               ...
# 168      0.618466          0.019096
# 169      0.806730          0.008075
# 170      0.733789          0.012761
# 171      0.000000          0.100000
# 172      0.611596          0.014639
#
# [173 rows x 5 columns]

# %%
## weekly

source_names_weekly_fixed = []
sigma_nxs_weekly_fixed = []
err_sigma_nxs_weekly_fixed = []
fvar_weekly_fixed = []
unc_fvar_weekly_fixed = []

for source_name in bin_weekly:
    
    file_name = f'4FGL+{source_name}.json'
    source_data = Read_json_file(file_name, 'weekly', 'fixed')
    source_df = source_data.dataframe
    source_dict = source_data.dictionary
    
    filtered_df = filter_source_flux(source_df)
    
    variability = Estimate_variability(filtered_df)
    sigma_nxs, err_sigma_nxs, fvar, err_fvar = variability.calculate_variability()
    
    source_names_weekly_fixed.append(source_name)
    sigma_nxs_weekly_fixed.append(sigma_nxs)
    err_sigma_nxs_weekly_fixed.append(err_sigma_nxs)
    fvar_weekly_fixed.append(fvar)
    unc_fvar_weekly_fixed.append(err_fvar)
    
df_variability_weekly_fixed = pd.DataFrame(list(zip(source_names_weekly_fixed,
                                                     sigma_nxs_weekly_fixed, err_sigma_nxs_weekly_fixed,
                                                     fvar_weekly_fixed, unc_fvar_weekly_fixed)),
                                            columns =['Source_Name', 'Norm_Excess_Var(weekly)', 'err_Norm_Excess_Var(weekly)',
                                                      'Fvar(weekly)', 'err_Fvar(weekly)'])
# Out:
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )

# %%
df_variability_weekly_fixed
# Out:
#       Source_Name  Norm_Excess_Var(weekly)  err_Norm_Excess_Var(weekly)  \
# 0    J0001.5+2113                 0.487329                     0.024063
# 1    J0009.3+5030                -0.062017                     0.012422
# 2    J0022.5+0608                 0.010893                     0.017715
# 3    J0030.3-4224                 0.398482                     0.030107
# 4    J0030.6-0212                 0.284148                     0.024906
# ..            ...                      ...                          ...
# 334  J2329.3-4955                 0.853292                     0.014831
# 335  J2331.0-2147                 0.247912                     0.027979
# 336  J2345.2-1555                 0.768994                     0.022072
# 337  J2347.0+5141                -0.051192                     0.016149
# 338  J2348.0-1630                 0.522539                     0.020512
#
#      Fvar(weekly)  err_Fvar(weekly)
# 0        0.698090          0.017235
# 1        0.000000          0.100000
# 2        0.104369          0.084866
# 3        0.631254          0.023847
# 4        0.533055          0.023361
# ..            ...               ...
# 334      0.923738          0.008028
# 335      0.497908          0.028097
# 336      0.876923          0.012585
# 337      0.000000          0.100000
# 338      0.722869          0.014188
#
# [339 rows x 5 columns]

# %%
## monthly

source_names_monthly_fixed = []
sigma_nxs_monthly_fixed = []
err_sigma_nxs_monthly_fixed = []
fvar_monthly_fixed = []
unc_fvar_monthly_fixed = []

for source_name in bin_monthly:
    
    file_name = f'4FGL+{source_name}.json'
    source_data = Read_json_file(file_name, 'monthly', 'fixed')
    source_df = source_data.dataframe
    source_dict = source_data.dictionary
    
    filtered_df = filter_source_flux(source_df)
    
    variability = Estimate_variability(filtered_df)
    sigma_nxs, err_sigma_nxs, fvar, err_fvar = variability.calculate_variability()
    
    source_names_monthly_fixed.append(source_name)
    sigma_nxs_monthly_fixed.append(sigma_nxs)
    err_sigma_nxs_monthly_fixed.append(err_sigma_nxs)
    fvar_monthly_fixed.append(fvar)
    unc_fvar_monthly_fixed.append(err_fvar)
    
df_variability_monthly_fixed = pd.DataFrame(list(zip(source_names_monthly_fixed,
                                                     sigma_nxs_monthly_fixed, err_sigma_nxs_monthly_fixed,
                                                     fvar_monthly_fixed, unc_fvar_monthly_fixed)),
                                            columns =['Source_Name', 'Norm_Excess_Var(monthly)', 'err_Norm_Excess_Var(monthly)',
                                                      'Fvar(monthly)', 'err_Fvar(monthly)'])
# Out:
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/variability_estimator.py:96: RuntimeWarning: invalid value encountered in sqrt
#   self.unc_normalized_excess_variance = np.sqrt( (term1)**2 + ( (term2)**2 * self.normalized_excess_variance) )

# %%
df_variability_monthly_fixed
# Out:
#       Source_Name  Norm_Excess_Var(monthly)  err_Norm_Excess_Var(monthly)  \
# 0    J0001.2-0747                 -0.090948                      0.002365
# 1    J0001.5+2113                  0.821839                      0.031841
# 2    J0004.4-4737                  0.090036                      0.040113
# 3    J0005.9+3824                 -0.005546                      0.026273
# 4    J0007.7+4008                 -0.072854                      0.006462
# ..            ...                       ...                           ...
# 798  J2347.0+5141                  0.059337                      0.017291
# 799  J2348.0-1630                  0.659113                      0.022290
# 800  J2355.7-3351                 -0.021041                      0.046153
# 801  J2358.3-1021                  0.151427                      0.035573
# 802  J2358.3+3830                 -0.109591                           NaN
#
#      Fvar(monthly)  err_Fvar(monthly)
# 0         0.000000           0.100000
# 1         0.906554           0.017561
# 2         0.300061           0.066842
# 3         0.000000           0.100000
# 4         0.000000           0.100000
# ..             ...                ...
# 798       0.243591           0.035492
# 799       0.811858           0.013728
# 800       0.000000           0.100000
# 801       0.389136           0.045707
# 802       0.000000           0.100000
#
# [803 rows x 5 columns]

# %%
## merging our estimates

df_filtered_4lac_luana_dr3 = df_filtered_4lac_luana_dr3.merge(df_variability_3days_fixed, on='Source_Name', how='left')
df_filtered_4lac_luana_dr3 = df_filtered_4lac_luana_dr3.merge(df_variability_weekly_fixed, on='Source_Name', how='left')
df_filtered_4lac_luana_dr3 = df_filtered_4lac_luana_dr3.merge(df_variability_monthly_fixed, on='Source_Name', how='left')

# %%
df_filtered_4lac_luana_dr3
# Out:
#        Source_Name SpectrumType CLASS SED_class  Variability_Index  \
# 0     J0001.2-0747     PowerLaw   bll       LSP          46.780693
# 1     J0001.5+2113  LogParabola  fsrq       ISP        1910.935791
# 2     J0003.3-1928  LogParabola   bcu       LSP          49.879936
# 3     J0004.3+4614  LogParabola  fsrq       LSP         139.036758
# 4     J0004.4-4737     PowerLaw  fsrq       LSP         153.286484
# ...            ...          ...   ...       ...                ...
# 1424  J2358.0-4601     PowerLaw   bcu       LSP          30.538687
# 1425  J2358.3-1021  LogParabola  fsrq       LSP         195.553940
# 1426  J2358.3+3830     PowerLaw   bll       NaN          42.173111
# 1427  J2359.0+3922     PowerLaw  fsrq       LSP          56.146664
# 1428  J2359.2-3134     PowerLaw  fsrq       LSP          82.691574
#
#       Frac_Variability  Unc_Frac_Variability  Spectrum_Flux_Estimated  \
# 0             0.406565              0.111870             9.825299e-09
# 1             0.996138              0.213478             6.391699e-08
# 2             0.591879              0.159972             3.715681e-09
# 3             1.016224              0.234237             1.086787e-08
# 4             0.823498              0.188146             1.070792e-08
# ...                ...                   ...                      ...
# 1424          0.477398              0.157409             5.184782e-09
# 1425          0.668076              0.150551             2.164930e-08
# 1426          0.567347              0.164919             4.248420e-09
# 1427          0.779921              0.203910             7.005793e-09
# 1428          1.012355              0.248552             5.776904e-09
#
#       Norm_Excess_Var(3-days)  err_Norm_Excess_Var(3-days)  Fvar(3-days)  \
# 0                         NaN                          NaN           NaN
# 1                         NaN                          NaN           NaN
# 2                         NaN                          NaN           NaN
# 3                         NaN                          NaN           NaN
# 4                         NaN                          NaN           NaN
# ...                       ...                          ...           ...
# 1424                      NaN                          NaN           NaN
# 1425                      NaN                          NaN           NaN
# 1426                      NaN                          NaN           NaN
# 1427                      NaN                          NaN           NaN
# 1428                      NaN                          NaN           NaN
#
#       err_Fvar(3-days)  Norm_Excess_Var(weekly)  err_Norm_Excess_Var(weekly)  \
# 0                  NaN                      NaN                          NaN
# 1                  NaN                 0.487329                     0.024063
# 2                  NaN                      NaN                          NaN
# 3                  NaN                      NaN                          NaN
# 4                  NaN                      NaN                          NaN
# ...                ...                      ...                          ...
# 1424               NaN                      NaN                          NaN
# 1425               NaN                      NaN                          NaN
# 1426               NaN                      NaN                          NaN
# 1427               NaN                      NaN                          NaN
# 1428               NaN                      NaN                          NaN
#
#       Fvar(weekly)  err_Fvar(weekly)  Norm_Excess_Var(monthly)  \
# 0              NaN               NaN                 -0.090948
# 1          0.69809          0.017235                  0.821839
# 2              NaN               NaN                       NaN
# 3              NaN               NaN                       NaN
# 4              NaN               NaN                  0.090036
# ...            ...               ...                       ...
# 1424           NaN               NaN                       NaN
# 1425           NaN               NaN                  0.151427
# 1426           NaN               NaN                 -0.109591
# 1427           NaN               NaN                       NaN
# 1428           NaN               NaN                       NaN
#
#       err_Norm_Excess_Var(monthly)  Fvar(monthly)  err_Fvar(monthly)
# 0                         0.002365       0.000000           0.100000
# 1                         0.031841       0.906554           0.017561
# 2                              NaN            NaN                NaN
# 3                              NaN            NaN                NaN
# 4                         0.040113       0.300061           0.066842
# ...                            ...            ...                ...
# 1424                           NaN            NaN                NaN
# 1425                      0.035573       0.389136           0.045707
# 1426                           NaN       0.000000           0.100000
# 1427                           NaN            NaN                NaN
# 1428                           NaN            NaN                NaN
#
# [1429 rows x 20 columns]

# %%
## merging our estimates

df_4lac_luana_dr3 = df_4lac_luana_dr3.merge(df_variability_3days_fixed, on='Source_Name', how='left')
df_4lac_luana_dr3 = df_4lac_luana_dr3.merge(df_variability_weekly_fixed, on='Source_Name', how='left')
df_4lac_luana_dr3 = df_4lac_luana_dr3.merge(df_variability_monthly_fixed, on='Source_Name', how='left')

# %%
df_4lac_luana_dr3
# Out:
#        Source_Name SpectrumType CLASS SED_class  Variability_Index  \
# 0     J0001.2+4741     PowerLaw   bcu       ISP          25.313953
# 1     J0001.2-0747     PowerLaw   bll       LSP          46.780693
# 2     J0001.4-0010     PowerLaw   bll       LSP           9.272764
# 3     J0001.5+2113  LogParabola  fsrq       ISP        1910.935791
# 4     J0001.6-4156     PowerLaw   bcu       HSP          26.393343
# ...            ...          ...   ...       ...                ...
# 3809  J2359.3+0215  LogParabola   bcu       LSP          16.065315
# 3810  J2359.3-2049     PowerLaw   bll       LSP          14.043210
# 3811  J2359.7-5041  LogParabola   bcu       LSP           7.732565
# 3812  J2359.9-3736     PowerLaw   bcu       LSP           8.143241
# 3813  J2359.9+3145  LogParabola   bcu       HSP          17.283010
#
#       Frac_Variability  Unc_Frac_Variability  Spectrum_Flux_Estimated  \
# 0             0.675882              0.312850             1.993321e-09
# 1             0.406565              0.111870             9.825299e-09
# 2             0.000000             10.000000             8.602307e-10
# 3             0.996138              0.213478             6.391699e-08
# 4             0.490977              0.175782             1.599132e-09
# ...                ...                   ...                      ...
# 3809          0.311971              0.625833             1.655760e-10
# 3810          0.177217              0.190973             3.021906e-09
# 3811          0.000000             10.000000             1.205902e-09
# 3812          0.000000             10.000000             2.216054e-09
# 3813          0.416743              0.248753             4.771791e-10
#
#       Norm_Excess_Var(3-days)  err_Norm_Excess_Var(3-days)  Fvar(3-days)  \
# 0                         NaN                          NaN           NaN
# 1                         NaN                          NaN           NaN
# 2                         NaN                          NaN           NaN
# 3                         NaN                          NaN           NaN
# 4                         NaN                          NaN           NaN
# ...                       ...                          ...           ...
# 3809                      NaN                          NaN           NaN
# 3810                      NaN                          NaN           NaN
# 3811                      NaN                          NaN           NaN
# 3812                      NaN                          NaN           NaN
# 3813                      NaN                          NaN           NaN
#
#       err_Fvar(3-days)  Norm_Excess_Var(weekly)  err_Norm_Excess_Var(weekly)  \
# 0                  NaN                      NaN                          NaN
# 1                  NaN                      NaN                          NaN
# 2                  NaN                      NaN                          NaN
# 3                  NaN                 0.487329                     0.024063
# 4                  NaN                      NaN                          NaN
# ...                ...                      ...                          ...
# 3809               NaN                      NaN                          NaN
# 3810               NaN                      NaN                          NaN
# 3811               NaN                      NaN                          NaN
# 3812               NaN                      NaN                          NaN
# 3813               NaN                      NaN                          NaN
#
#       Fvar(weekly)  err_Fvar(weekly)  Norm_Excess_Var(monthly)  \
# 0              NaN               NaN                       NaN
# 1              NaN               NaN                 -0.090948
# 2              NaN               NaN                       NaN
# 3          0.69809          0.017235                  0.821839
# 4              NaN               NaN                       NaN
# ...            ...               ...                       ...
# 3809           NaN               NaN                       NaN
# 3810           NaN               NaN                       NaN
# 3811           NaN               NaN                       NaN
# 3812           NaN               NaN                       NaN
# 3813           NaN               NaN                       NaN
#
#       err_Norm_Excess_Var(monthly)  Fvar(monthly)  err_Fvar(monthly)
# 0                              NaN            NaN                NaN
# 1                         0.002365       0.000000           0.100000
# 2                              NaN            NaN                NaN
# 3                         0.031841       0.906554           0.017561
# 4                              NaN            NaN                NaN
# ...                            ...            ...                ...
# 3809                           NaN            NaN                NaN
# 3810                           NaN            NaN                NaN
# 3811                           NaN            NaN                NaN
# 3812                           NaN            NaN                NaN
# 3813                           NaN            NaN                NaN
#
# [3814 rows x 20 columns]

# %%
## Histograms

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

sns.histplot(df_filtered_4lac_luana_dr3['Norm_Excess_Var(3-days)'], bins=30, kde=True, ax=axes[0])
axes[0].set_title('Excess Variance - 3-days Distribution')

sns.histplot(df_filtered_4lac_luana_dr3['Norm_Excess_Var(weekly)'], bins=30, kde=True, ax=axes[1])
axes[1].set_title('Excess Variance - Weekly Distribution')

sns.histplot(df_filtered_4lac_luana_dr3['Norm_Excess_Var(monthly)'], bins=30, kde=True, ax=axes[2])
axes[2].set_title('Excess Variance - Monthly Distribution')


plt.tight_layout()

plt.savefig('plots/excess_variance_distributions.png')

plt.show()

# %% [markdown]
# ## Plots

# %%
## plot V_NXS(month) +/- eV_NXS(month) versus V_NXS(3-day) +/- eV_NXS(3-day)

plt.figure(figsize=(8,6), dpi=300)

x = df_filtered_4lac_luana_dr3[df_filtered_4lac_luana_dr3['Norm_Excess_Var(3-days)'].notna()]

plt.errorbar(df_filtered_4lac_luana_dr3['Norm_Excess_Var(monthly)'], df_filtered_4lac_luana_dr3['Norm_Excess_Var(3-days)'],
             xerr=df_filtered_4lac_luana_dr3['err_Norm_Excess_Var(monthly)'], yerr=df_filtered_4lac_luana_dr3['err_Norm_Excess_Var(3-days)'],
             fmt='o', markersize=5, alpha=0.5, label='Normalized Excess Variance')

plt.xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=12)
plt.ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-day)', fontsize=12)
plt.title(f'Normalized Excess Variance Monthly vs. 3-day cadences - {len(x)} points', fontsize=12)
plt.legend()

# plt.xscale('log')
# plt.yscale('log')

plt.xlim(plt.ylim())
# plt.ylim(plt.xlim())

plt.grid(True)
plt.savefig('plots/monthly_vs_3days.png',dpi=300)
plt.show()

# %%
## plot V_NXS(month) +/- eV_NXS(month) versus V_NXS(3-day) +/- eV_NXS(3-day)

plt.figure(figsize=(8,6), dpi=300)

x = df_filtered_4lac_luana_dr3[df_filtered_4lac_luana_dr3['Norm_Excess_Var(3-days)'].notna()]
# x = x[x > 0]

plt.errorbar(df_filtered_4lac_luana_dr3['Norm_Excess_Var(monthly)'], df_filtered_4lac_luana_dr3['Norm_Excess_Var(3-days)'],
             xerr=df_filtered_4lac_luana_dr3['err_Norm_Excess_Var(monthly)'], yerr=df_filtered_4lac_luana_dr3['err_Norm_Excess_Var(3-days)'],
             fmt='o', markersize=5, alpha=0.5, label='Normalized Excess Variance')

plt.xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=12)
plt.ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-day)', fontsize=12)
plt.title(f'Normalized Excess Variance Monthly vs. 3-day cadences - {len(x)}? points', fontsize=12)
plt.legend()

plt.xscale('log')
plt.yscale('log')

plt.xlim(plt.ylim())
# plt.ylim(plt.xlim())

plt.grid(True)
plt.savefig('plots/monthly_vs_3days_log.png',dpi=300)
plt.show()

# %%
# x = df_filtered_4lac_luana_dr3[df_filtered_4lac_luana_dr3['Norm_Excess_Var(monthly)'].notna()]
# y = df_filtered_4lac_luana_dr3[df_filtered_4lac_luana_dr3['Norm_Excess_Var(3-days)'].notna()]
# x_err = df_filtered_4lac_luana_dr3[df_filtered_4lac_luana_dr3['err_Norm_Excess_Var(monthly)'].notna()]
# y_err = df_filtered_4lac_luana_dr3[df_filtered_4lac_luana_dr3['err_Norm_Excess_Var(3-days)'].notna()]

# %%
x = df_filtered_4lac_luana_dr3['Norm_Excess_Var(monthly)']
y = df_filtered_4lac_luana_dr3['Norm_Excess_Var(3-days)']
x_err = df_filtered_4lac_luana_dr3['err_Norm_Excess_Var(monthly)']
y_err = df_filtered_4lac_luana_dr3['err_Norm_Excess_Var(3-days)']

# %%
len(x)
# Out:
# 1429

# %%
## filter out non-positive values
valid_indices = (x > 0) & (y > 0)

x = x[valid_indices]
y = y[valid_indices]
x_err = x_err[valid_indices]
y_err = y_err[valid_indices]

# %%
len(x)
# Out:
# 138

# %%
## Log transformation
log_x = np.log(x)
log_y = np.log(y)
log_x_err = x_err / x  # relative error in log scale
log_y_err = y_err / y  # relative error in log scale

# %%
from scipy.odr import ODR, Model, RealData

def linear_func(B, x):
    return B[0] * x + B[1]

linear_model = Model(linear_func)
data = RealData(x, y, sx=x_err, sy=y_err)

odr = ODR(data, linear_model, beta0=[1., 2.])
output = odr.run()
output.pprint()

## extract the slope and its uncertainty
slope = output.beta[0]
slope_err = output.sd_beta[0]

intercept = output.beta[1]
intercept_err = output.sd_beta[1]

print(f"Slope: {slope}")
print(f"Slope uncertainty: {slope_err}")
print(f"Residual Variance: {output.res_var}")
print(f"Intercept: {intercept}")
print(f"Intercept uncertainty: {intercept_err}")
# Out:
# Beta: [ 1.1214271 -0.2049548]
# Beta Std Error: [0.04148812 0.03788139]
# Beta Covariance: [[ 7.85095912e-06 -5.15904599e-06]
#  [-5.15904599e-06  6.54526435e-06]]
# Residual Variance: 219.24247371138685
# Inverse Condition #: 0.357364602587703
# Reason(s) for Halting:
#   Sum of squares convergence
# Slope: 1.1214271020369573
# Slope uncertainty: 0.04148811515096698
# Residual Variance: 219.24247371138685
# Intercept: -0.2049547965627669
# Intercept uncertainty: 0.03788139315481315

# %%
plt.figure(figsize=(8, 6), dpi=300)

plt.errorbar(x, y, xerr=x_err, yerr=y_err, fmt='o', markersize=5, alpha=0.5, label='Normalized Excess Variance')

x_fit = np.linspace(min(x), max(x), 100)
y_fit = slope * x_fit + intercept
plt.plot(x_fit, y_fit, color='red', label=f'Fit: y = {slope:.2f}({slope_err:.2f}) * x + {intercept:.2f} ({intercept_err:.2f})')

plt.xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=12)
plt.ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-day)', fontsize=12)
plt.title(f'Normalized Excess Variance Monthly vs. 3-day cadences - {len(x)} points', fontsize=12)
plt.legend()

# plt.xscale('log')
# plt.yscale('log')

plt.xlim(plt.ylim())
# plt.ylim(plt.xlim())

plt.savefig('plots/monthly_vs_3days_fit.png')

plt.grid(True)
plt.show()

# %%
def linear_func(B, x):
    return B[0] * x + B[1]

linear_model = Model(linear_func)
data = RealData(log_x, log_y, sx=log_x_err, sy=log_y_err)

odr = ODR(data, linear_model, beta0=[1., 2.])
output = odr.run()
output.pprint()

## extract the slope and its uncertainty
slope = output.beta[0]
slope_err = output.sd_beta[0]

intercept = output.beta[1]
intercept_err = output.sd_beta[1]

print(f"Slope: {slope}")
print(f"Slope uncertainty: {slope_err}")
print(f"Residual Variance: {output.res_var}")
print(f"Intercept: {intercept}")
print(f"Intercept uncertainty: {intercept_err}")
# Out:
# Beta: [ 1.31677389 -0.23549642]
# Beta Std Error: [0.05360368 0.04506861]
# Beta Covariance: [[ 1.49652150e-05 -9.43391384e-06]
#  [-9.43391384e-06  1.05789356e-05]]
# Residual Variance: 192.00222853351812
# Inverse Condition #: 0.34543361027089003
# Reason(s) for Halting:
#   Sum of squares convergence
# Slope: 1.316773890761005
# Slope uncertainty: 0.05360368116308593
# Residual Variance: 192.00222853351812
# Intercept: -0.23549641789640607
# Intercept uncertainty: 0.04506860562212793

# %%
plt.figure(figsize=(8, 6), dpi=300)

# Plotting the data with error bars
plt.errorbar(x, y, xerr=x_err, yerr=y_err, fmt='o', markersize=5, alpha=0.5, label='Normalized Excess Variance')

# Plotting the regression line
x_fit = np.linspace(min(x), max(x), 100)
log_x_fit = np.log(x_fit)
log_y_fit = slope * log_x_fit + intercept
y_fit = np.exp(log_y_fit)
plt.plot(x_fit, y_fit, color='red', label=f'Fit: y = {slope:.2f}({slope_err:.2f}) * x + {intercept:.2f} ({intercept_err:.2f})')
# plt.plot(x_fit, y_fit, color='purple', label=f'Fit: y = {np.exp(intercept):.2e} * x^{slope:.2f}')

plt.xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=12)
plt.ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-day)', fontsize=12)
plt.title(f'Normalized Excess Variance Monthly vs. 3-day cadences - {len(log_x)} points', fontsize=12)
plt.legend()

plt.xscale('log')
plt.yscale('log')

plt.ylim(10**(-2.5),1e1)

plt.savefig('plots/monthly_vs_3days_log_fit.png')

plt.grid(True)
plt.show()

# %%
df_filtered_4lac_luana_dr3.head()
# Out:
#     Source_Name SpectrumType CLASS SED_class  Variability_Index  \
# 0  J0001.2-0747     PowerLaw   bll       LSP          46.780693
# 1  J0001.5+2113  LogParabola  fsrq       ISP        1910.935791
# 2  J0003.3-1928  LogParabola   bcu       LSP          49.879936
# 3  J0004.3+4614  LogParabola  fsrq       LSP         139.036758
# 4  J0004.4-4737     PowerLaw  fsrq       LSP         153.286484
#
#    Frac_Variability  Unc_Frac_Variability  Spectrum_Flux_Estimated  \
# 0          0.406565              0.111870             9.825299e-09
# 1          0.996138              0.213478             6.391699e-08
# 2          0.591879              0.159972             3.715681e-09
# 3          1.016224              0.234237             1.086787e-08
# 4          0.823498              0.188146             1.070792e-08
#
#    Norm_Excess_Var(3-days)  err_Norm_Excess_Var(3-days)  Fvar(3-days)  \
# 0                      NaN                          NaN           NaN
# 1                      NaN                          NaN           NaN
# 2                      NaN                          NaN           NaN
# 3                      NaN                          NaN           NaN
# 4                      NaN                          NaN           NaN
#
#    err_Fvar(3-days)  Norm_Excess_Var(weekly)  err_Norm_Excess_Var(weekly)  \
# 0               NaN                      NaN                          NaN
# 1               NaN                 0.487329                     0.024063
# 2               NaN                      NaN                          NaN
# 3               NaN                      NaN                          NaN
# 4               NaN                      NaN                          NaN
#
#    Fvar(weekly)  err_Fvar(weekly)  Norm_Excess_Var(monthly)  \
# 0           NaN               NaN                 -0.090948
# 1       0.69809          0.017235                  0.821839
# 2           NaN               NaN                       NaN
# 3           NaN               NaN                       NaN
# 4           NaN               NaN                  0.090036
#
#    err_Norm_Excess_Var(monthly)  Fvar(monthly)  err_Fvar(monthly)
# 0                      0.002365       0.000000           0.100000
# 1                      0.031841       0.906554           0.017561
# 2                           NaN            NaN                NaN
# 3                           NaN            NaN                NaN
# 4                      0.040113       0.300061           0.066842

# %%
df_4lac_luana_dr3.head()
# Out:
#     Source_Name SpectrumType CLASS SED_class  Variability_Index  \
# 0  J0001.2+4741     PowerLaw   bcu       ISP          25.313953
# 1  J0001.2-0747     PowerLaw   bll       LSP          46.780693
# 2  J0001.4-0010     PowerLaw   bll       LSP           9.272764
# 3  J0001.5+2113  LogParabola  fsrq       ISP        1910.935791
# 4  J0001.6-4156     PowerLaw   bcu       HSP          26.393343
#
#    Frac_Variability  Unc_Frac_Variability  Spectrum_Flux_Estimated  \
# 0          0.675882              0.312850             1.993321e-09
# 1          0.406565              0.111870             9.825299e-09
# 2          0.000000             10.000000             8.602307e-10
# 3          0.996138              0.213478             6.391699e-08
# 4          0.490977              0.175782             1.599132e-09
#
#    Norm_Excess_Var(3-days)  err_Norm_Excess_Var(3-days)  Fvar(3-days)  \
# 0                      NaN                          NaN           NaN
# 1                      NaN                          NaN           NaN
# 2                      NaN                          NaN           NaN
# 3                      NaN                          NaN           NaN
# 4                      NaN                          NaN           NaN
#
#    err_Fvar(3-days)  Norm_Excess_Var(weekly)  err_Norm_Excess_Var(weekly)  \
# 0               NaN                      NaN                          NaN
# 1               NaN                      NaN                          NaN
# 2               NaN                      NaN                          NaN
# 3               NaN                 0.487329                     0.024063
# 4               NaN                      NaN                          NaN
#
#    Fvar(weekly)  err_Fvar(weekly)  Norm_Excess_Var(monthly)  \
# 0           NaN               NaN                       NaN
# 1           NaN               NaN                 -0.090948
# 2           NaN               NaN                       NaN
# 3       0.69809          0.017235                  0.821839
# 4           NaN               NaN                       NaN
#
#    err_Norm_Excess_Var(monthly)  Fvar(monthly)  err_Fvar(monthly)
# 0                           NaN            NaN                NaN
# 1                      0.002365       0.000000           0.100000
# 2                           NaN            NaN                NaN
# 3                      0.031841       0.906554           0.017561
# 4                           NaN            NaN                NaN

# %%
## plots and table

# %%
table_4lac_luana_dr3 = Table.from_pandas(df_4lac_luana_dr3)
table_filtered_4lac_luana_dr3 = Table.from_pandas(df_filtered_4lac_luana_dr3) 

table_4lac_luana_dr3.write('./resulting_catalogs/df_4lac_luana_dr3.fits', format='fits', overwrite=True)
table_4lac_luana_dr3.write('./resulting_catalogs/df_4lac_luana_dr3.ecsv', format='ascii.ecsv', overwrite=True)
table_filtered_4lac_luana_dr3.write('./resulting_catalogs/df_filtered_4lac_luana_dr3.fits', format='fits', overwrite=True)
table_filtered_4lac_luana_dr3.write('./resulting_catalogs/df_filtered_4lac_luana_dr3.ecsv', format='ascii.ecsv', overwrite=True)

# %%
## plotting a few to check

for source_name in bin_3days[:5]:
    
    file_name = f'4FGL+{source_name}.json'
    source_data = Read_json_file(file_name, '3-days', 'fixed')
    source_df = source_data.dataframe
    source_dict = source_data.dictionary
    
    filtered_df = filter_source_flux(source_df)
    
    plots = Plots(file_name[5:-5], df_agn_pop_4lac_dr3, source_dict, filtered_df)
    plots.lightcurve_complete('3-days', 1.1e-6)
    plots.lightcurve_filtered('3-days', 1.1e-6)
    # plots.spectrum(power=12, x_dlim=0.06, x_ulim=120, y_dlim=10, y_ulim=150)
    plots.exposure()

# %%
## plotting a few to check

for source_name in bin_monthly[:5]:
    
    file_name = f'4FGL+{source_name}.json'
    source_data = Read_json_file(file_name, '3-days', 'fixed')
    source_df = source_data.dataframe
    source_dict = source_data.dictionary
    
    filtered_df = filter_source_flux(source_df)
    
    plots = Plots(file_name[5:-5], df_agn_pop_4lac_dr3, source_dict, filtered_df)
    plots.lightcurve_complete('3-days', 1.1e-6)
    plots.lightcurve_filtered('3-days', 1.1e-6)
    # plots.spectrum(power=12, x_dlim=0.06, x_ulim=120, y_dlim=10, y_ulim=150)
    plots.exposure()
