# %%
from read_json import *
from spectrum_integrate import *
from plots import *
from source_filter import *
from variability_estimator import *

# %%
import glob
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.table import Table

# %%
## import

path_4lac_dr3_catalog = '../4LAC_catalog_generator_v3/resulting_catalogs/agn_pop_4lac_dr3.ecsv'
table_agn_pop_4lac_dr3 = Table.read(path_4lac_dr3_catalog, format='ascii.ecsv')
df_agn_pop_4lac_dr3 = table_agn_pop_4lac_dr3.to_pandas()

df_agn_pop_4lac_dr3.head()
# Out:
#     Source_Name  RAJ2000    DEJ2000  Redshift SpectrumType  Pivot_Energy  \
# 0  J0001.2+4741   0.3126  47.685902      -inf     PowerLaw   2420.575195
# 1  J0001.2-0747   0.3151  -7.797100      -inf     PowerLaw   1721.603882
# 2  J0001.4-0010   0.3717  -0.169900  0.461516     PowerLaw   4307.082520
# 3  J0001.5+2113   0.3815  21.218300  1.106000  LogParabola    329.773743
# 4  J0001.6-4156   0.4165 -41.942501      -inf     PowerLaw   4047.030029
#
#    PL_Flux_Density  PL_Index  LP_Flux_Density  LP_Index   LP_beta CLASS  \
# 0     2.156031e-14  2.271696     2.196550e-14  2.254081  0.012156   bcu
# 1     2.656894e-13  2.116692     2.842831e-13  2.078927  0.051182   bll
# 2     6.067356e-15  1.939160     6.488817e-15  1.661223  0.132438   bll
# 3     4.683598e-11  2.654060     5.371562e-11  2.514159  0.159319  fsrq
# 4     1.881541e-14  1.775175     2.131597e-14  1.693865  0.072754   bcu
#
#   SED_class  Variability_Index  Frac_Variability  Unc_Frac_Variability  \
# 0       ISP          25.313953          0.675882              0.312850
# 1       LSP          46.780693          0.406565              0.111870
# 2       LSP           9.272764          0.000000             10.000000
# 3       ISP        1910.935791          0.996138              0.213478
# 4       HSP          26.393343          0.490977              0.175782
#
#        Flux1000  Unc_Flux1000
# 0  1.259796e-10  2.877197e-11
# 1  7.471219e-10  5.041939e-11
# 2  1.082246e-10  2.914440e-11
# 3  1.347354e-09  6.172809e-11
# 4  2.821817e-10  3.090882e-11

# %%
## saving our changes in a separate dataframe

df_4lac_luana_dr3 = df_agn_pop_4lac_dr3.copy()

# %%
df_4lac_luana_dr3 = df_4lac_luana_dr3.drop(df_4lac_luana_dr3.columns[5:11], axis=1)
df_4lac_luana_dr3 = df_4lac_luana_dr3.drop(columns=['RAJ2000', 'DEJ2000', 'Redshift', 'Flux1000', 'Unc_Flux1000'])

# %%
## adding spectrum flux calculations

spectrum_flux_values = []
spectrum_flux_Flux1000comparison = []

for index, row in df_4lac_luana_dr3.iterrows():
    source_name = row['Source_Name']
    
    ## integrate from 1-100 GeV
    spectrum_flux_test, diff_flux_test, spec_type_test = integrate_spectrum_flux(source_name, df_agn_pop_4lac_dr3, 1, 100)
    spectrum_flux_Flux1000comparison.append(spectrum_flux_test)
    
    ## integrate from 0.1-100 GeV
    spectrum_flux, diff_flux, spec_type = integrate_spectrum_flux(source_name, df_agn_pop_4lac_dr3, 0.1, 100)
    spectrum_flux_values.append(spectrum_flux)

df_4lac_luana_dr3['Spectrum_Flux_Estimated'] = spectrum_flux_values
# Out:
# /Users/luanareis/Documents/GitHub/CTA_AGN_Pop_Variability/4LAC_variability_analysis/spectrum_integrate.py:71: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   flux_from_spectrum = integrate.quad(lambda x: K * ((x/E_0)**(- alpha - beta * np.log(x/E_0))),

# %%
## getting a list of the downloaded sources

folder_path = '../4LAC_lightcurve_downloader_v3/resulting_catalogs/input_lightcurve_downloads_v3/fixed_indexed_lightcurves/3days_ts1_fixedindex_lightcurves'

## glob to get all .json files in the folder
json_files = glob.glob(os.path.join(folder_path, '*.json'))
json_file_names = [os.path.basename(file)[5:17] for file in json_files]

len(json_file_names)
# Out:
# 1429

# %%
## creating a df for the downloaded sources

df_filtered_4lac_luana_dr3 = df_4lac_luana_dr3[df_4lac_luana_dr3['Source_Name'].isin(json_file_names)].copy()
df_filtered_4lac_luana_dr3.reset_index(drop=True, inplace=True)

print(len(df_filtered_4lac_luana_dr3))
# Out:
# 1429

# %%
json_source_names = df_filtered_4lac_luana_dr3['Source_Name'].tolist()

len(json_source_names)
# Out:
# 1429

# %%
# ## Testing

# file_name = f'4FGL+J0010.6+2043.json'
# # file_name = f'4FGL+J0726.4-4727.json'

# source_data = Read_json_file(file_name, '3-days', 'fixed')
# source_df = source_data.dataframe
# source_dict = source_data.dictionary

# filtered_df, median_df, inputed_df, n_unconstrained = check_and_fill_bins(source_df)

# %% [markdown]
# ## Monthly NEX estimates

# %%
#### open light curve files & FILTER
## input invalid bins with flux = 0 and flux_error = flux[previous_bin]

## monthly

source_names_monthly = []
UL_bright_ratio_monthly = []

## case zero
nExcess_monthly_zero = []
unc_nExcess_monthly_zero = []
fvar_monthly_zero = []
unc_fvar_monthly_zero = []


for source_name in json_source_names:
    file_name = f'4FGL+{source_name}.json'
    source_data = Read_json_file(file_name, 'monthly', 'fixed')
    source_df = source_data.dataframe
    source_dict = source_data.dictionary
    
    filtered_df, median_df, inputed_df, n_unconstrained = check_and_fill_bins(source_df)
    
    ## UL check
    if len(median_df['flux'].dropna()) != 0:
        bright_ratio = n_unconstrained / len(median_df['flux'].dropna())
    else:
        bright_ratio = 10.0
        
    UL_bright_ratio_monthly.append(bright_ratio)
    
    variability = Estimate_variability(inputed_df)
    sigma_nxs, err_sigma_nxs, fvar, err_fvar = variability.calculate_variability()

    source_names_monthly.append(source_name)

    nExcess_monthly_zero.append(sigma_nxs)
    unc_nExcess_monthly_zero.append(err_sigma_nxs)
    fvar_monthly_zero.append(fvar)
    unc_fvar_monthly_zero.append(err_fvar)
    
df_variability_monthly_zero = pd.DataFrame(list(zip(source_names_monthly, UL_bright_ratio_monthly,
                                                     nExcess_monthly_zero, unc_nExcess_monthly_zero,
                                                     fvar_monthly_zero, unc_fvar_monthly_zero)),
                                            columns =['Source_Name', 'Bright_Ratio', 'Norm_Excess_Var(monthly)', 'Unc_Norm_Excess_Var(monthly)',
                                                      'Frac_Variability(monthly)', 'Unc_Frac_Variability(monthly)'])

# %%
df_variability_monthly_zero
# Out:
#        Source_Name  Bright_Ratio  Norm_Excess_Var(monthly)  \
# 0     J0001.2-0747      0.738318                 -0.831176
# 1     J0001.5+2113      0.553719                  2.312904
# 2     J0003.3-1928      1.724638                 -2.850514
# 3     J0004.3+4614      3.700000                 -2.072027
# 4     J0004.4-4737      1.561644                  0.652796
# ...            ...           ...                       ...
# 1424  J2358.0-4601      1.984127                 -2.122770
# 1425  J2358.3-1021      1.065934                  0.300956
# 1426  J2358.3+3830      1.540541                 -2.238749
# 1427  J2359.0+3922      2.418182                 -5.269139
# 1428  J2359.2-3134      4.222222                -13.207607
#
#       Unc_Norm_Excess_Var(monthly)  Frac_Variability(monthly)  \
# 0                         0.204850                   0.000000
# 1                         0.130572                   1.520823
# 2                         0.547161                   0.000000
# 3                         0.774564                   0.000000
# 4                         0.269674                   0.807958
# ...                            ...                        ...
# 1424                      0.549519                   0.000000
# 1425                      0.200933                   0.548595
# 1426                      0.446069                   0.000000
# 1427                      0.865150                   0.000000
# 1428                      1.949774                   0.000000
#
#       Unc_Frac_Variability(monthly)
# 0                          0.100000
# 1                          0.042928
# 2                          0.100000
# 3                          0.100000
# 4                          0.166886
# ...                             ...
# 1424                       0.100000
# 1425                       0.183135
# 1426                       0.100000
# 1427                       0.100000
# 1428                       0.100000
#
# [1429 rows x 6 columns]

# %% [markdown]
# ## Selection of sources which show significant variability on a monthly timescale
#
# --> only select sources with $\sigma_{NXS}^{2}$(monthly) - 3*err$[\sigma_{NXS}^{2}]$(monthly) > 0

# %%
table_variability_monthly_zero = Table.from_pandas(df_variability_monthly_zero)

# %%
## monthly significant 3 sigma

selected_indices = []

for index, row in enumerate(table_variability_monthly_zero):
    
    ## Check if 'Norm_Excess_Var(monthly)' and 'Unc_Norm_Excess_Var(monthly)' are not None and not NaN
    if (row['Norm_Excess_Var(monthly)'] is not None and not pd.isna(row['Norm_Excess_Var(monthly)'])) and \
       (row['Unc_Norm_Excess_Var(monthly)'] is not None and not pd.isna(row['Unc_Norm_Excess_Var(monthly)'])):
        
        ## 3 sigma criteria
        if row['Norm_Excess_Var(monthly)'] - 3 * row['Unc_Norm_Excess_Var(monthly)'] > 0:
            selected_indices.append(index)  # add index to list

if selected_indices:
    table_selected_monthly = table_variability_monthly_zero[selected_indices]
else:
    print("No rows satisfy the condition.")

# %%
selected_table_monthly = table_selected_monthly.to_pandas()

# %%
selected_table_monthly
# Out:
#       Source_Name  Bright_Ratio  Norm_Excess_Var(monthly)  \
# 0    J0001.5+2113      0.553719                  2.312904
# 1    J0009.3+5030      0.099415                  0.201056
# 2    J0010.6+2043      2.615385                  3.203006
# 3    J0011.4+0057      0.918367                  1.127854
# 4    J0017.5-0514      1.043478                  1.407208
# ..            ...           ...                       ...
# 470  J2329.3-4955      0.198718                  2.379554
# 471  J2331.0-2147      0.358209                  0.700785
# 472  J2345.2-1555      0.268966                  2.171191
# 473  J2347.0+5141      0.068182                  0.141772
# 474  J2348.0-1630      0.125749                  0.983079
#
#      Unc_Norm_Excess_Var(monthly)  Frac_Variability(monthly)  \
# 0                        0.130572                   1.520823
# 1                        0.032965                   0.448393
# 2                        0.526970                   1.789695
# 3                        0.226527                   1.062005
# 4                        0.203640                   1.186258
# ..                            ...                        ...
# 470                      0.025538                   1.542580
# 471                      0.101058                   0.837129
# 472                      0.045225                   1.473496
# 473                      0.028442                   0.376526
# 474                      0.032670                   0.991503
#
#      Unc_Frac_Variability(monthly)
# 0                         0.042928
# 1                         0.036759
# 2                         0.147223
# 3                         0.106651
# 4                         0.085833
# ..                             ...
# 470                       0.008278
# 471                       0.060360
# 472                       0.015346
# 473                       0.037769
# 474                       0.016475
#
# [475 rows x 6 columns]

# %%
selected_table_monthly['Source_Name']
# Out:
# 0      J0001.5+2113
# 1      J0009.3+5030
# 2      J0010.6+2043
# 3      J0011.4+0057
# 4      J0017.5-0514
#            ...
# 470    J2329.3-4955
# 471    J2331.0-2147
# 472    J2345.2-1555
# 473    J2347.0+5141
# 474    J2348.0-1630
# Name: Source_Name, Length: 475, dtype: object

# %%
## bright_ratio cut

subset_bright_ratio = selected_table_monthly[selected_table_monthly['Bright_Ratio'] < 1.0]

# %%
subset_bright_ratio
# Out:
#       Source_Name  Bright_Ratio  Norm_Excess_Var(monthly)  \
# 0    J0001.5+2113      0.553719                  2.312904
# 1    J0009.3+5030      0.099415                  0.201056
# 3    J0011.4+0057      0.918367                  1.127854
# 6    J0022.5+0608      0.093023                  0.316199
# 7    J0030.3-4224      0.197452                  1.002037
# ..            ...           ...                       ...
# 470  J2329.3-4955      0.198718                  2.379554
# 471  J2331.0-2147      0.358209                  0.700785
# 472  J2345.2-1555      0.268966                  2.171191
# 473  J2347.0+5141      0.068182                  0.141772
# 474  J2348.0-1630      0.125749                  0.983079
#
#      Unc_Norm_Excess_Var(monthly)  Frac_Variability(monthly)  \
# 0                        0.130572                   1.520823
# 1                        0.032965                   0.448393
# 3                        0.226527                   1.062005
# 6                        0.037404                   0.562316
# 7                        0.061208                   1.001018
# ..                            ...                        ...
# 470                      0.025538                   1.542580
# 471                      0.101058                   0.837129
# 472                      0.045225                   1.473496
# 473                      0.028442                   0.376526
# 474                      0.032670                   0.991503
#
#      Unc_Frac_Variability(monthly)
# 0                         0.042928
# 1                         0.036759
# 3                         0.106651
# 6                         0.033259
# 7                         0.030573
# ..                             ...
# 470                       0.008278
# 471                       0.060360
# 472                       0.015346
# 473                       0.037769
# 474                       0.016475
#
# [407 rows x 6 columns]

# %% [markdown]
# ## 3-days and Weekly

# %%
#### open light curve files & FILTER
## input invalid bins with flux = 0 and flux_error = flux[previous_bin]

## 3-days

source_names_3days = []
UL_bright_ratio_3days = []

## case zero
nExcess_3days_zero = []
unc_nExcess_3days_zero = []
fvar_3days_zero = []
unc_fvar_3days_zero = []


for source_name in json_source_names:
    file_name = f'4FGL+{source_name}.json'
    source_data = Read_json_file(file_name, '3-days', 'fixed')
    source_df = source_data.dataframe
    source_dict = source_data.dictionary
    
    filtered_df, median_df, inputed_df, n_unconstrained = check_and_fill_bins(source_df)
    
    ## UL check
    if len(median_df['flux'].dropna()) != 0:
        bright_ratio = n_unconstrained / len(median_df['flux'].dropna())
    else:
        bright_ratio = 10.0
        
    ## 50% cut
    if bright_ratio < 1.0:
        # print(bright_ratio)
        UL_bright_ratio_3days.append(bright_ratio)
        
        variability = Estimate_variability(inputed_df)
        sigma_nxs, err_sigma_nxs, fvar, err_fvar = variability.calculate_variability()
    
        source_names_3days.append(source_name)
        
        nExcess_3days_zero.append(sigma_nxs)
        unc_nExcess_3days_zero.append(err_sigma_nxs)
        fvar_3days_zero.append(fvar)
        unc_fvar_3days_zero.append(err_fvar)
    
df_variability_3days_zero = pd.DataFrame(list(zip(source_names_3days, UL_bright_ratio_3days,
                                                     nExcess_3days_zero, unc_nExcess_3days_zero,
                                                     fvar_3days_zero, unc_fvar_3days_zero)),
                                            columns =['Source_Name', 'Bright_Ratio', 'Norm_Excess_Var(3_days)', 'Unc_Norm_Excess_Var(3_days)',
                                                      'Frac_Variability(3_days)', 'Unc_Frac_Variability(3_days)'])

# %%
df_variability_3days_zero
# Out:
#       Source_Name  Bright_Ratio  Norm_Excess_Var(3_days)  \
# 0    J0050.7-0929      0.853202                -1.033326
# 1    J0102.8+5824      0.830059                 0.278461
# 2    J0108.6+0134      0.166150                 1.561703
# 3    J0112.1+2245      0.251847                 0.388735
# 4    J0120.4-2701      0.781161                -1.266344
# ..            ...           ...                      ...
# 110  J2236.5-1433      0.733826                 2.324791
# 111  J2243.9+2021      0.744403                -0.747378
# 112  J2253.9+1609      0.068000                 4.208276
# 113  J2329.3-4955      0.796154                 2.648098
# 114  J2348.0-1630      0.767925                 0.932303
#
#      Unc_Norm_Excess_Var(3_days)  Frac_Variability(3_days)  \
# 0                       0.079326                  0.000000
# 1                       0.054488                  0.527694
# 2                       0.021274                  1.249681
# 3                       0.023720                  0.623487
# 4                       0.082922                  0.000000
# ..                           ...                       ...
# 110                     0.078249                  1.524726
# 111                     0.070669                  0.000000
# 112                     0.015420                  2.051408
# 113                     0.042912                  1.627298
# 114                     0.060512                  0.965558
#
#      Unc_Frac_Variability(3_days)
# 0                        0.100000
# 1                        0.051628
# 2                        0.008512
# 3                        0.019022
# 4                        0.100000
# ..                            ...
# 110                      0.025660
# 111                      0.100000
# 112                      0.003758
# 113                      0.013185
# 114                      0.031335
#
# [115 rows x 6 columns]

# %%
#### open light curve files & FILTER
## input invalid bins with flux = 0 and flux_error = flux[previous_bin]

## weekly

source_names_weekly = []
UL_bright_ratio_weekly = []

## case zero
nExcess_weekly_zero = []
unc_nExcess_weekly_zero = []
fvar_weekly_zero = []
unc_fvar_weekly_zero = []


for source_name in json_source_names:
    file_name = f'4FGL+{source_name}.json'
    source_data = Read_json_file(file_name, 'weekly', 'fixed')
    source_df = source_data.dataframe
    source_dict = source_data.dictionary
    
    filtered_df, median_df, inputed_df, n_unconstrained = check_and_fill_bins(source_df)
    
    ## UL check
    if len(median_df['flux'].dropna()) != 0:
        bright_ratio = n_unconstrained / len(median_df['flux'].dropna())
    else:
        bright_ratio = 10.0
        
    ## 50% cut
    if bright_ratio < 1.0:
        # print(bright_ratio)
        UL_bright_ratio_weekly.append(bright_ratio)
        
        variability = Estimate_variability(inputed_df)
        sigma_nxs, err_sigma_nxs, fvar, err_fvar = variability.calculate_variability()
    
        source_names_weekly.append(source_name)
        
        nExcess_weekly_zero.append(sigma_nxs)
        unc_nExcess_weekly_zero.append(err_sigma_nxs)
        fvar_weekly_zero.append(fvar)
        unc_fvar_weekly_zero.append(err_fvar)
    
df_variability_weekly_zero = pd.DataFrame(list(zip(source_names_weekly, UL_bright_ratio_weekly,
                                                     nExcess_weekly_zero, unc_nExcess_weekly_zero,
                                                     fvar_weekly_zero, unc_fvar_weekly_zero)),
                                            columns =['Source_Name', 'Bright_Ratio', 'Norm_Excess_Var(weekly)', 'Unc_Norm_Excess_Var(weekly)',
                                                      'Frac_Variability(weekly)', 'Unc_Frac_Variability(weekly)'])

# %%
df_variability_weekly_zero
# Out:
#       Source_Name  Bright_Ratio  Norm_Excess_Var(weekly)  \
# 0    J0009.3+5030      0.632653                -0.644885
# 1    J0022.5+0608      0.687631                -0.184832
# 2    J0030.3-4224      0.800000                 0.766840
# 3    J0033.5-1921      0.558140                -0.499343
# 4    J0035.9+5950      0.862791                -0.781439
# ..            ...           ...                      ...
# 231  J2325.4-3559      0.907363                -0.277695
# 232  J2329.3-4955      0.480663                 2.533819
# 233  J2345.2-1555      0.656379                 2.442947
# 234  J2347.0+5141      0.592445                -0.531640
# 235  J2348.0-1630      0.422261                 1.310998
#
#      Unc_Norm_Excess_Var(weekly)  Frac_Variability(weekly)  \
# 0                       0.085637                  0.000000
# 1                       0.070174                  0.000000
# 2                       0.098406                  0.875694
# 3                       0.073549                  0.000000
# 4                       0.121826                  0.000000
# ..                           ...                       ...
# 231                     0.102305                  0.000000
# 232                     0.039486                  1.591798
# 233                     0.061198                  1.562993
# 234                     0.080203                  0.000000
# 235                     0.050840                  1.144988
#
#      Unc_Frac_Variability(weekly)
# 0                        0.100000
# 1                        0.100000
# 2                        0.056188
# 3                        0.100000
# 4                        0.100000
# ..                            ...
# 231                      0.100000
# 232                      0.012403
# 233                      0.019577
# 234                      0.100000
# 235                      0.022201
#
# [236 rows x 6 columns]

# %%
## unifying in a single dataframe

# %%
## merging our estimates

df_4lac_luana_dr3 = df_4lac_luana_dr3.merge(df_variability_3days_zero, on='Source_Name', how='left')
df_4lac_luana_dr3 = df_4lac_luana_dr3.merge(df_variability_weekly_zero, on='Source_Name', how='left')
df_4lac_luana_dr3 = df_4lac_luana_dr3.merge(df_variability_monthly_zero, on='Source_Name', how='left')

# %%
## merging our estimates

df_filtered_4lac_luana_dr3 = df_filtered_4lac_luana_dr3.merge(df_variability_3days_zero, on='Source_Name', how='left')
df_filtered_4lac_luana_dr3 = df_filtered_4lac_luana_dr3.merge(df_variability_weekly_zero, on='Source_Name', how='left')
df_filtered_4lac_luana_dr3 = df_filtered_4lac_luana_dr3.merge(selected_table_monthly, on='Source_Name', how='left')

# %%
## merging our estimates

selected_sources_df = subset_bright_ratio.merge(df_variability_3days_zero, on='Source_Name', how='left')

# %%
## a few plots

# %%
## Histograms

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

sns.histplot(df_4lac_luana_dr3['Norm_Excess_Var(3_days)'], bins=30, kde=True, ax=axes[0])
axes[0].set_title(f"Excess Variance - 3-days Distribution ({len(df_4lac_luana_dr3['Norm_Excess_Var(3_days)'].dropna())} sources)")

sns.histplot(df_4lac_luana_dr3['Norm_Excess_Var(weekly)'], bins=30, kde=True, ax=axes[1])
axes[1].set_title(f"Excess Variance - Weekly Distribution ({len(df_4lac_luana_dr3['Norm_Excess_Var(weekly)'].dropna())} sources)")

sns.histplot(df_4lac_luana_dr3['Norm_Excess_Var(monthly)'], bins=30, kde=True, ax=axes[2])
axes[2].set_title(f"Excess Variance - Monthly Distribution ({len(df_4lac_luana_dr3['Norm_Excess_Var(monthly)'].dropna())} sources)")

plt.tight_layout()

plt.savefig('plots/distributionsdf_4lac_luana_all.png')

plt.show()

# %%
## Histograms

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

sns.histplot(df_filtered_4lac_luana_dr3['Norm_Excess_Var(3_days)'], bins=30, kde=True, ax=axes[0])
axes[0].set_title(f"Excess Variance - 3-days Distribution ({len(df_filtered_4lac_luana_dr3['Norm_Excess_Var(3_days)'].dropna())} sources)")

sns.histplot(df_filtered_4lac_luana_dr3['Norm_Excess_Var(weekly)'], bins=30, kde=True, ax=axes[1])
axes[1].set_title(f"Excess Variance - Weekly Distribution ({len(df_filtered_4lac_luana_dr3['Norm_Excess_Var(weekly)'].dropna())} sources)")

sns.histplot(df_filtered_4lac_luana_dr3['Norm_Excess_Var(monthly)'], bins=30, kde=True, ax=axes[2])
axes[2].set_title(f"Excess Variance - Monthly Distribution ({len(df_filtered_4lac_luana_dr3['Norm_Excess_Var(monthly)'].dropna())} sources)")

plt.tight_layout()

plt.savefig('plots/distributions_df_filtered.png')

plt.show()

# %%
## Histograms

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

sns.histplot(df_filtered_4lac_luana_dr3['Norm_Excess_Var(3_days)'], bins=30, kde=True, ax=axes[0])
axes[0].set_title(f"Excess Variance - 3-days Distribution ({len(df_filtered_4lac_luana_dr3['Norm_Excess_Var(3_days)'].dropna())} sources)")

sns.histplot(df_filtered_4lac_luana_dr3['Norm_Excess_Var(weekly)'], bins=30, kde=True, ax=axes[1])
axes[1].set_title(f"Excess Variance - Weekly Distribution ({len(df_filtered_4lac_luana_dr3['Norm_Excess_Var(weekly)'].dropna())} sources)")

sns.histplot(selected_sources_df['Norm_Excess_Var(monthly)'], bins=30, kde=True, ax=axes[2])
axes[2].set_title(f"Excess Variance - Monthly Distribution ({len(selected_sources_df['Norm_Excess_Var(monthly)'].dropna())} sources)")

plt.tight_layout()

plt.savefig('plots/distributions_selected_sources_df.png')

plt.show()

# %%
selected_sources_df
# Out:
#       Source_Name  Bright_Ratio_x  Norm_Excess_Var(monthly)  \
# 0    J0001.5+2113        0.553719                  2.312904
# 1    J0009.3+5030        0.099415                  0.201056
# 2    J0011.4+0057        0.918367                  1.127854
# 3    J0022.5+0608        0.093023                  0.316199
# 4    J0030.3-4224        0.197452                  1.002037
# ..            ...             ...                       ...
# 402  J2329.3-4955        0.198718                  2.379554
# 403  J2331.0-2147        0.358209                  0.700785
# 404  J2345.2-1555        0.268966                  2.171191
# 405  J2347.0+5141        0.068182                  0.141772
# 406  J2348.0-1630        0.125749                  0.983079
#
#      Unc_Norm_Excess_Var(monthly)  Frac_Variability(monthly)  \
# 0                        0.130572                   1.520823
# 1                        0.032965                   0.448393
# 2                        0.226527                   1.062005
# 3                        0.037404                   0.562316
# 4                        0.061208                   1.001018
# ..                            ...                        ...
# 402                      0.025538                   1.542580
# 403                      0.101058                   0.837129
# 404                      0.045225                   1.473496
# 405                      0.028442                   0.376526
# 406                      0.032670                   0.991503
#
#      Unc_Frac_Variability(monthly)  Bright_Ratio_y  Norm_Excess_Var(3_days)  \
# 0                         0.042928             NaN                      NaN
# 1                         0.036759             NaN                      NaN
# 2                         0.106651             NaN                      NaN
# 3                         0.033259             NaN                      NaN
# 4                         0.030573             NaN                      NaN
# ..                             ...             ...                      ...
# 402                       0.008278        0.796154                 2.648098
# 403                       0.060360             NaN                      NaN
# 404                       0.015346             NaN                      NaN
# 405                       0.037769             NaN                      NaN
# 406                       0.016475        0.767925                 0.932303
#
#      Unc_Norm_Excess_Var(3_days)  Frac_Variability(3_days)  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ..                           ...                       ...
# 402                     0.042912                  1.627298
# 403                          NaN                       NaN
# 404                          NaN                       NaN
# 405                          NaN                       NaN
# 406                     0.060512                  0.965558
#
#      Unc_Frac_Variability(3_days)
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 402                      0.013185
# 403                           NaN
# 404                           NaN
# 405                           NaN
# 406                      0.031335
#
# [407 rows x 11 columns]

# %%
## plot NXS(3-days) vs. NXS(monthly)

plt.figure(figsize=(8, 6), dpi=300)

## filter for non-NaN values in 3-days column
x = selected_sources_df[selected_sources_df['Norm_Excess_Var(3_days)'].notna()]

plt.errorbar(
    x['Norm_Excess_Var(monthly)'], x['Norm_Excess_Var(3_days)'],
    xerr=x['Unc_Norm_Excess_Var(monthly)'], yerr=x['Unc_Norm_Excess_Var(3_days)'],
    fmt='o', markersize=6, alpha=0.6, label='Normalized Excess Variance'
)

## add diagonal line (y = x)
plt.plot([x['Norm_Excess_Var(monthly)'].min(), x['Norm_Excess_Var(monthly)'].max()],
         [x['Norm_Excess_Var(monthly)'].min(), x['Norm_Excess_Var(monthly)'].max()],
         '--', color='black', label='$y = x$', alpha=0.7)

plt.xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=14)
plt.ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-days)', fontsize=14)
plt.title(f'NXS(3-days) vs. NXS(monthly) - {len(x)} sources', fontsize=16)

# plt.xscale('log')
# plt.yscale('log')

# plt.ylim(plt.xlim())
plt.xlim(plt.ylim())

plt.grid(visible=True, which="both", linestyle='--', linewidth=0.5, alpha=0.7)
plt.legend(fontsize=12)

plt.savefig('plots/selected_NEX.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
## LOG SCALE: plot NXS(3-days) vs. NXS(monthly)

plt.figure(figsize=(8, 6), dpi=300)

## filter for non-NaN values in 3-days column
x = selected_sources_df[selected_sources_df['Norm_Excess_Var(3_days)'].notna()]

plt.errorbar(
    x['Norm_Excess_Var(monthly)'], x['Norm_Excess_Var(3_days)'],
    xerr=x['Unc_Norm_Excess_Var(monthly)'], yerr=x['Unc_Norm_Excess_Var(3_days)'],
    fmt='o', markersize=6, alpha=0.6, label='Normalized Excess Variance'
)

plt.xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=14)
plt.ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-days)', fontsize=14)
plt.title(f'NXS(3-days) vs. NXS(monthly) - {len(x)} sources', fontsize=16)

plt.xscale('log')
plt.yscale('log')

# plt.ylim(plt.xlim())
plt.xlim(plt.ylim())

plt.grid(visible=True, which="both", linestyle='--', linewidth=0.5, alpha=0.7)
plt.legend(fontsize=12)

plt.savefig('plots/selected_NEX_log.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
## LOG SCALE: plot NXS(3-days) vs. NXS(monthly)

plt.figure(figsize=(8, 6), dpi=300)

## filter for non-NaN values in 3-days column
x = selected_sources_df[selected_sources_df['Norm_Excess_Var(3_days)'].notna()]

plt.errorbar(
    x['Norm_Excess_Var(monthly)'], x['Norm_Excess_Var(3_days)'],
    xerr=x['Unc_Norm_Excess_Var(monthly)'], yerr=x['Unc_Norm_Excess_Var(3_days)'],
    fmt='o', markersize=6, alpha=0.6, label='Normalized Excess Variance'
)

## add diagonal line (y = x)
plt.plot([x['Norm_Excess_Var(monthly)'].min(), x['Norm_Excess_Var(monthly)'].max()],
         [x['Norm_Excess_Var(monthly)'].min(), x['Norm_Excess_Var(monthly)'].max()],
         '--', color='black', label='$y = x$', alpha=0.7)

plt.xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=14)
plt.ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-days)', fontsize=14)
plt.title(f'NXS(3-days) vs. NXS(monthly) - {len(x)} sources', fontsize=16)

plt.xscale('log')
plt.yscale('log')

# plt.ylim(plt.xlim())
plt.xlim(plt.ylim())

plt.grid(visible=True, which="both", linestyle='--', linewidth=0.5, alpha=0.7)
plt.legend(fontsize=12)

plt.savefig('plots/selected_NEX_yx.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
## sources in Lucas analysis regarding Imposed Energy cutoff [TeV]

# PKS 1510-089: J1512.8-0906
# 3C 66A: J0222.6+4302

# %%
## check main sources

# Mkn 421: J1104.4+3812
# Mkn 501: J1653.8+3945
# PKS 2155-304: J2158.8-3013
# 3C 273: J1229.0+0202

main_sources = ["J1104.4+3812", "J1653.8+3945", "J2158.8-3013", "J1229.0+0202", "J1512.8-0906", "J0222.6+4302"]

matched_sources = [source for source in main_sources if source in subset_bright_ratio['Source_Name'].values]

print("Matched sources:", matched_sources)
# Out:
# Matched sources: ['J1104.4+3812', 'J1653.8+3945', 'J2158.8-3013', 'J1229.0+0202', 'J1512.8-0906', 'J0222.6+4302']

# %% [markdown]
# ## Fit using scipy

# %%
from scipy.optimize import curve_fit

## model y = a * x^b
def model(x, a, b):
    return a * x**b

data = selected_sources_df[selected_sources_df['Norm_Excess_Var(3_days)'].notna()]
x = data['Norm_Excess_Var(monthly)']
y = data['Norm_Excess_Var(3_days)']
xerr = data['Unc_Norm_Excess_Var(monthly)']
yerr = data['Unc_Norm_Excess_Var(3_days)']

## fit with both a and b free
popt_free, pcov_free = curve_fit(model, x, y, sigma=yerr, absolute_sigma=True)
a_free, b_free = popt_free

## fit with a = 1 fixed
def model_fixed(x, a):
    return x**a

popt_fixed, pcov_fixed = curve_fit(model_fixed, x, y, sigma=yerr, absolute_sigma=True)
a_fixed = popt_fixed[0]

## create x-range for plotting the fits
x_fit = np.logspace(np.log10(x.min()), np.log10(x.max()), 100)
y_fit_free = model(x_fit, a_free, b_free)
y_fit_fixed = model_fixed(x_fit, a_fixed)

# %%
## square roots of the diagonal elements of the covariance matrices
## (pcov_free and pcov_fixed)

## a & b free
a_free_err, b_free_err = np.sqrt(np.diag(pcov_free))
print(f"Fit with a and b free:")
print(f"  a = {a_free:.4e} ± {a_free_err:.4e}")
print(f"  b = {b_free:.4f} ± {b_free_err:.4f}")

## a free & b=1
a_fixed_err = np.sqrt(np.diag(pcov_fixed))[0]
print(f"\nFit with a fixed (a=1):")
print(f"  a = {a_fixed:.4e} ± {a_fixed_err:.4e}")
# Out:
# Fit with a and b free:
#   a = 1.2771e+00 ± 3.3238e-03
#   b = 1.1255 ± 0.0031
#
# Fit with a fixed (a=1):
#   a = 1.3384e+00 ± 2.3053e-03

# %%
plt.figure(figsize=(8, 6), dpi=300)
plt.errorbar(x, y, xerr=xerr, yerr=yerr, fmt='o', markersize=5, alpha=0.5,
             label='Normalized Excess Variance', capsize=2, elinewidth=1, capthick=1.2)

plt.plot(x_fit, y_fit_free, label=f'Fit (free): $y = ({a_free:.3f} ± {a_free_err:.3f}) * x^{{{b_free:.3f} ± {b_free_err:.3f}}}$', color='green', linestyle='--')
plt.plot(x_fit, y_fit_fixed, label=f'Fit (fixed): $y = x^{{{a_fixed:.3f} ± {a_fixed_err:.3f}}}$', color='red', linestyle='--')

plt.xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=14)
plt.ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-days)', fontsize=14)
plt.title(f'NXS(3-days) vs. NXS(monthly) - {len(x)} sources', fontsize=16)

plt.xscale('log')
plt.yscale('log')

plt.xlim(1e-2, 1e1)

plt.grid(visible=True, which="both", linestyle='--', linewidth=0.5, alpha=0.7)
plt.legend(fontsize=12)

plt.savefig('plots/selected_log_fit_scipy.png', dpi=300)
plt.show()

# %%
# Define figure dimensions
fig, axes = plt.subplots(1, 2, figsize=(14, 6), dpi=300, constrained_layout=True)

# First Plot: Free Fit
axes[0].errorbar(x, y, xerr=xerr, yerr=yerr, fmt='o', markersize=5, alpha=0.5,
                 color='blue', label='Data', capsize=2, elinewidth=1, capthick=1.2)
axes[0].plot(x_fit, y_fit_free, label=f'Fit (Free): $y = ({a_free:.3f} \pm {a_free_err:.3f}) \cdot x^{{{b_free:.3f} \pm {b_free_err:.3f}}}$', color='green', linestyle='--')

axes[0].set_xscale('log')
axes[0].set_yscale('log')
axes[0].set_xlim(1e-2, 1e1)
axes[0].set_xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=12)
axes[0].set_ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-days)', fontsize=12)
axes[0].set_title('Fit (Free Parameters)', fontsize=14)
axes[0].legend(fontsize=10)
axes[0].grid(visible=True, which="both", linestyle='--', linewidth=0.5, alpha=0.7)

# Second Plot: Fixed Fit
axes[1].errorbar(x, y, xerr=xerr, yerr=yerr, fmt='o', markersize=5, alpha=0.5,
                 color='blue', label='Data', capsize=2, elinewidth=1, capthick=1.2)
axes[1].plot(x_fit, y_fit_fixed, label=f'Fit (Fixed): $y = x^{{{a_fixed:.3f} \pm {a_fixed_err:.3f}}}$', color='red', linestyle='--')

axes[1].set_xscale('log')
axes[1].set_yscale('log')
axes[1].set_xlim(1e-2, 1e1)
axes[1].set_xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=12)
axes[1].set_ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-days)', fontsize=12)
axes[1].set_title('Fit (Fixed Parameter)', fontsize=14)
axes[1].legend(fontsize=10)
axes[1].grid(visible=True, which="both", linestyle='--', linewidth=0.5, alpha=0.7)

# Save and Show
plt.savefig('plots/separate_fits_scipy.png', dpi=300)
plt.show()

# %% [markdown]
# ## Fit using ODR

# %%
from scipy.odr import Model, Data, ODR
import numpy as np

# Define the models
def model_free(params, x):
    a, b = params
    return a * x**b

def model_fixed(params, x):
    b = params[0]  # Only b is free; a is implicitly 1
    return x**b

# Prepare data for ODR
data = selected_sources_df[selected_sources_df['Norm_Excess_Var(3_days)'].notna()]
x = data['Norm_Excess_Var(monthly)'].values
y = data['Norm_Excess_Var(3_days)'].values
xerr = data['Unc_Norm_Excess_Var(monthly)'].values
yerr = data['Unc_Norm_Excess_Var(3_days)'].values

# Free fit: both a and b are free
data_free = Data(x, y, we=1/yerr, wd=1/xerr)  # Weights inversely proportional to uncertainties
model_free_odr = Model(model_free)
odr_free = ODR(data_free, model_free_odr, beta0=[1.0, 1.0])  # Initial guesses for a and b
output_free = odr_free.run()
a_free, b_free = output_free.beta
a_free_err, b_free_err = np.sqrt(np.diag(output_free.cov_beta))

print("ODR Fit (a and b free):")
print(f"  a = {a_free:.4e} ± {a_free_err:.4e}")
print(f"  b = {b_free:.4f} ± {b_free_err:.4f}")

# Fixed fit: a is fixed at 1, only b is free
data_fixed = Data(x, y, we=1/yerr, wd=1/xerr)
model_fixed_odr = Model(model_fixed)
odr_fixed = ODR(data_fixed, model_fixed_odr, beta0=[1.0])  # Initial guess for b
output_fixed = odr_fixed.run()
a_fixed = output_fixed.beta[0]
a_fixed_err = np.sqrt(output_fixed.cov_beta[0, 0])

print("\nODR Fit (a fixed, b free):")
print(f"  b = {a_fixed:.4f} ± {a_fixed_err:.4f}")

# Generate fits for plotting
x_fit = np.logspace(np.log10(x.min()), np.log10(x.max()), 100)
y_fit_free = model_free([a_free, b_free], x_fit)
y_fit_fixed = model_fixed([a_fixed], x_fit)
# Out:
# ODR Fit (a and b free):
#   a = 1.1968e+00 ± 3.4625e-02
#   b = 1.1957 ± 0.0334
#
# ODR Fit (a fixed, b free):
#   b = 1.3717 ± 0.0220
# /var/folders/sk/6dg2gqpn01x3m5hwkj90qkgw0000gp/T/ipykernel_6709/4172326978.py:7: RuntimeWarning: invalid value encountered in power
#   return a * x**b
# /var/folders/sk/6dg2gqpn01x3m5hwkj90qkgw0000gp/T/ipykernel_6709/4172326978.py:11: RuntimeWarning: invalid value encountered in power
#   return x**b

# %%
plt.figure(figsize=(8, 6), dpi=300)
plt.errorbar(x, y, xerr=xerr, yerr=yerr, fmt='o', markersize=5, alpha=0.5,
             label='Normalized Excess Variance', capsize=2, elinewidth=1, capthick=1.2)

plt.plot(x_fit, y_fit_free, label=f'Fit (free): $y = ({a_free:.3f} ± {a_free_err:.3f}) * x^{{{b_free:.3f} ± {b_free_err:.3f}}}$', color='green', linestyle='--')
plt.plot(x_fit, y_fit_fixed, label=f'Fit (fixed): $y = x^{{{a_fixed:.3f} ± {a_fixed_err:.3f}}}$', color='red', linestyle='--')

plt.xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=14)
plt.ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-days)', fontsize=14)
plt.title(f'NXS(3-days) vs. NXS(monthly) - {len(x)} sources', fontsize=16)

plt.xscale('log')
plt.yscale('log')

plt.xlim(1e-2, 1e1)

plt.grid(visible=True, which="both", linestyle='--', linewidth=0.5, alpha=0.7)
plt.legend(fontsize=12)

plt.savefig('plots/selected_log_fit_ODR.png', dpi=300)
plt.show()

# %%
# Define figure dimensions
fig, axes = plt.subplots(1, 2, figsize=(14, 6), dpi=300, constrained_layout=True)

# First Plot: Free Fit
axes[0].errorbar(x, y, xerr=xerr, yerr=yerr, fmt='o', markersize=5, alpha=0.5,
                 color='blue', label='Data', capsize=2, elinewidth=1, capthick=1.2)
axes[0].plot(x_fit, y_fit_free, label=f'Fit (Free): $y = ({a_free:.3f} \pm {a_free_err:.3f}) \cdot x^{{{b_free:.3f} \pm {b_free_err:.3f}}}$', color='green', linestyle='--')

axes[0].set_xscale('log')
axes[0].set_yscale('log')
axes[0].set_xlim(1e-2, 1e1)
axes[0].set_xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=12)
axes[0].set_ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-days)', fontsize=12)
axes[0].set_title('Fit (Free Parameters)', fontsize=14)
axes[0].legend(fontsize=10)
axes[0].grid(visible=True, which="both", linestyle='--', linewidth=0.5, alpha=0.7)

# Second Plot: Fixed Fit
axes[1].errorbar(x, y, xerr=xerr, yerr=yerr, fmt='o', markersize=5, alpha=0.5,
                 color='blue', label='Data', capsize=2, elinewidth=1, capthick=1.2)
axes[1].plot(x_fit, y_fit_fixed, label=f'Fit (Fixed): $y = x^{{{a_fixed:.3f} \pm {a_fixed_err:.3f}}}$', color='red', linestyle='--')

axes[1].set_xscale('log')
axes[1].set_yscale('log')
axes[1].set_xlim(1e-2, 1e1)
axes[1].set_xlabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (monthly)', fontsize=12)
axes[1].set_ylabel('$\sigma_{\mathrm{NXS}}^{2} \pm \mathrm{err}(\sigma_{\mathrm{NXS}}^{2})$ (3-days)', fontsize=12)
axes[1].set_title('Fit (Fixed Parameter)', fontsize=14)
axes[1].legend(fontsize=10)
axes[1].grid(visible=True, which="both", linestyle='--', linewidth=0.5, alpha=0.7)

# Save and Show
plt.savefig('plots/separate_fits_ODR.png', dpi=300)
plt.show()

# %%
## bootstrap - 80% / 90% of points many times

# %%
df_4lac_luana_dr3
# Out:
#        Source_Name SpectrumType CLASS SED_class  Variability_Index  \
# 0     J0001.2+4741     PowerLaw   bcu       ISP          25.313953
# 1     J0001.2-0747     PowerLaw   bll       LSP          46.780693
# 2     J0001.4-0010     PowerLaw   bll       LSP           9.272764
# 3     J0001.5+2113  LogParabola  fsrq       ISP        1910.935791
# 4     J0001.6-4156     PowerLaw   bcu       HSP          26.393343
# ...            ...          ...   ...       ...                ...
# 3809  J2359.3+0215  LogParabola   bcu       LSP          16.065315
# 3810  J2359.3-2049     PowerLaw   bll       LSP          14.043210
# 3811  J2359.7-5041  LogParabola   bcu       LSP           7.732565
# 3812  J2359.9-3736     PowerLaw   bcu       LSP           8.143241
# 3813  J2359.9+3145  LogParabola   bcu       HSP          17.283010
#
#       Frac_Variability  Unc_Frac_Variability  Spectrum_Flux_Estimated  \
# 0             0.675882              0.312850             1.993321e-09
# 1             0.406565              0.111870             9.825299e-09
# 2             0.000000             10.000000             8.602307e-10
# 3             0.996138              0.213478             6.391699e-08
# 4             0.490977              0.175782             1.599132e-09
# ...                ...                   ...                      ...
# 3809          0.311971              0.625833             1.655760e-10
# 3810          0.177217              0.190973             3.021906e-09
# 3811          0.000000             10.000000             1.205902e-09
# 3812          0.000000             10.000000             2.216054e-09
# 3813          0.416743              0.248753             4.771791e-10
#
#       Bright_Ratio_x  Norm_Excess_Var(3_days)  ...  Bright_Ratio_y  \
# 0                NaN                      NaN  ...             NaN
# 1                NaN                      NaN  ...             NaN
# 2                NaN                      NaN  ...             NaN
# 3                NaN                      NaN  ...             NaN
# 4                NaN                      NaN  ...             NaN
# ...              ...                      ...  ...             ...
# 3809             NaN                      NaN  ...             NaN
# 3810             NaN                      NaN  ...             NaN
# 3811             NaN                      NaN  ...             NaN
# 3812             NaN                      NaN  ...             NaN
# 3813             NaN                      NaN  ...             NaN
#
#       Norm_Excess_Var(weekly)  Unc_Norm_Excess_Var(weekly)  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 3809                      NaN                          NaN
# 3810                      NaN                          NaN
# 3811                      NaN                          NaN
# 3812                      NaN                          NaN
# 3813                      NaN                          NaN
#
#       Frac_Variability(weekly)  Unc_Frac_Variability(weekly)  Bright_Ratio  \
# 0                          NaN                           NaN           NaN
# 1                          NaN                           NaN      0.738318
# 2                          NaN                           NaN           NaN
# 3                          NaN                           NaN      0.553719
# 4                          NaN                           NaN           NaN
# ...                        ...                           ...           ...
# 3809                       NaN                           NaN           NaN
# 3810                       NaN                           NaN           NaN
# 3811                       NaN                           NaN           NaN
# 3812                       NaN                           NaN           NaN
# 3813                       NaN                           NaN           NaN
#
#       Norm_Excess_Var(monthly)  Unc_Norm_Excess_Var(monthly)  \
# 0                          NaN                           NaN
# 1                    -0.831176                      0.204850
# 2                          NaN                           NaN
# 3                     2.312904                      0.130572
# 4                          NaN                           NaN
# ...                        ...                           ...
# 3809                       NaN                           NaN
# 3810                       NaN                           NaN
# 3811                       NaN                           NaN
# 3812                       NaN                           NaN
# 3813                       NaN                           NaN
#
#       Frac_Variability(monthly)  Unc_Frac_Variability(monthly)
# 0                           NaN                            NaN
# 1                      0.000000                       0.100000
# 2                           NaN                            NaN
# 3                      1.520823                       0.042928
# 4                           NaN                            NaN
# ...                         ...                            ...
# 3809                        NaN                            NaN
# 3810                        NaN                            NaN
# 3811                        NaN                            NaN
# 3812                        NaN                            NaN
# 3813                        NaN                            NaN
#
# [3814 rows x 23 columns]

# %%
df_filtered_4lac_luana_dr3
# Out:
#        Source_Name SpectrumType CLASS SED_class  Variability_Index  \
# 0     J0001.2-0747     PowerLaw   bll       LSP          46.780693
# 1     J0001.5+2113  LogParabola  fsrq       ISP        1910.935791
# 2     J0003.3-1928  LogParabola   bcu       LSP          49.879936
# 3     J0004.3+4614  LogParabola  fsrq       LSP         139.036758
# 4     J0004.4-4737     PowerLaw  fsrq       LSP         153.286484
# ...            ...          ...   ...       ...                ...
# 1424  J2358.0-4601     PowerLaw   bcu       LSP          30.538687
# 1425  J2358.3-1021  LogParabola  fsrq       LSP         195.553940
# 1426  J2358.3+3830     PowerLaw   bll       NaN          42.173111
# 1427  J2359.0+3922     PowerLaw  fsrq       LSP          56.146664
# 1428  J2359.2-3134     PowerLaw  fsrq       LSP          82.691574
#
#       Frac_Variability  Unc_Frac_Variability  Spectrum_Flux_Estimated  \
# 0             0.406565              0.111870             9.825299e-09
# 1             0.996138              0.213478             6.391699e-08
# 2             0.591879              0.159972             3.715681e-09
# 3             1.016224              0.234237             1.086787e-08
# 4             0.823498              0.188146             1.070792e-08
# ...                ...                   ...                      ...
# 1424          0.477398              0.157409             5.184782e-09
# 1425          0.668076              0.150551             2.164930e-08
# 1426          0.567347              0.164919             4.248420e-09
# 1427          0.779921              0.203910             7.005793e-09
# 1428          1.012355              0.248552             5.776904e-09
#
#       Bright_Ratio_x  Norm_Excess_Var(3_days)  ...  Bright_Ratio_y  \
# 0                NaN                      NaN  ...             NaN
# 1                NaN                      NaN  ...             NaN
# 2                NaN                      NaN  ...             NaN
# 3                NaN                      NaN  ...             NaN
# 4                NaN                      NaN  ...             NaN
# ...              ...                      ...  ...             ...
# 1424             NaN                      NaN  ...             NaN
# 1425             NaN                      NaN  ...             NaN
# 1426             NaN                      NaN  ...             NaN
# 1427             NaN                      NaN  ...             NaN
# 1428             NaN                      NaN  ...             NaN
#
#       Norm_Excess_Var(weekly)  Unc_Norm_Excess_Var(weekly)  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 1424                      NaN                          NaN
# 1425                      NaN                          NaN
# 1426                      NaN                          NaN
# 1427                      NaN                          NaN
# 1428                      NaN                          NaN
#
#       Frac_Variability(weekly)  Unc_Frac_Variability(weekly)  Bright_Ratio  \
# 0                          NaN                           NaN           NaN
# 1                          NaN                           NaN      0.553719
# 2                          NaN                           NaN           NaN
# 3                          NaN                           NaN           NaN
# 4                          NaN                           NaN           NaN
# ...                        ...                           ...           ...
# 1424                       NaN                           NaN           NaN
# 1425                       NaN                           NaN           NaN
# 1426                       NaN                           NaN           NaN
# 1427                       NaN                           NaN           NaN
# 1428                       NaN                           NaN           NaN
#
#       Norm_Excess_Var(monthly)  Unc_Norm_Excess_Var(monthly)  \
# 0                          NaN                           NaN
# 1                     2.312904                      0.130572
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 1424                       NaN                           NaN
# 1425                       NaN                           NaN
# 1426                       NaN                           NaN
# 1427                       NaN                           NaN
# 1428                       NaN                           NaN
#
#       Frac_Variability(monthly)  Unc_Frac_Variability(monthly)
# 0                           NaN                            NaN
# 1                      1.520823                       0.042928
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
# ...                         ...                            ...
# 1424                        NaN                            NaN
# 1425                        NaN                            NaN
# 1426                        NaN                            NaN
# 1427                        NaN                            NaN
# 1428                        NaN                            NaN
#
# [1429 rows x 23 columns]

# %%
## add column in our final selected table

# selected_sources_df['Norm_Excess_Var_Extrapolated(3_days)'] = selected_sources_df['Norm_Excess_Var(monthly)']**a

# %%
table_4lac_luana_dr3 = Table.from_pandas(df_4lac_luana_dr3)
table_filtered_4lac_luana_dr3 = Table.from_pandas(df_filtered_4lac_luana_dr3) 
table_selected_monthly = Table.from_pandas(selected_sources_df)

# %%
table_selected_monthly
# Out:
# <Table length=407>
# Source_Name     Bright_Ratio_x   ... Unc_Frac_Variability(3_days)
#    str12           float64       ...           float64
# ------------ ------------------- ... ----------------------------
# J0001.5+2113  0.5537190082644629 ...                           --
# J0009.3+5030 0.09941520467836257 ...                           --
# J0011.4+0057  0.9183673469387755 ...                           --
# J0022.5+0608 0.09302325581395349 ...                           --
# J0030.3-4224 0.19745222929936307 ...                           --
# J0030.6-0212  0.5537190082644629 ...                           --
#          ...                 ... ...                          ...
# J2327.5+0939  0.5932203389830508 ...                           --
# J2328.3-4036             0.46875 ...                           --
# J2329.3-4955  0.1987179487179487 ...         0.013185195072426948
# J2331.0-2147  0.3582089552238806 ...                           --
# J2345.2-1555  0.2689655172413793 ...                           --
# J2347.0+5141 0.06818181818181818 ...                           --
# J2348.0-1630 0.12574850299401197 ...          0.03133515586049535

# %%
## save table

table_selected_monthly.write('./resulting_catalogs/selected_sources_monthly.fits', format='fits', overwrite=True)
table_selected_monthly.write('./resulting_catalogs/selected_sources_monthly.ecsv', format='ascii.ecsv', overwrite=True)

table_4lac_luana_dr3.write('./resulting_catalogs/df_4lac_luana_dr3.fits', format='fits', overwrite=True)
table_4lac_luana_dr3.write('./resulting_catalogs/df_4lac_luana_dr3.ecsv', format='ascii.ecsv', overwrite=True)

table_filtered_4lac_luana_dr3.write('./resulting_catalogs/df_filtered_4lac_luana_dr3.fits', format='fits', overwrite=True)
table_filtered_4lac_luana_dr3.write('./resulting_catalogs/df_filtered_4lac_luana_dr3.ecsv', format='ascii.ecsv', overwrite=True)
